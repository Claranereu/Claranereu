# %% [markdown]
# <a href="https://colab.research.google.com/github/Claranereu/Claranereu/blob/main/Pale%20Blue%20Dot%20HydroCultiva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df= r'/content/soilsurface - Worksheet.csv'
soildata = pd.read_csv(df)
soildata

# %%
soildata.isnull().sum()
# Out:
# time                     0
# Soil surface moisture    0
# dtype: int64

# %%
soildata.info
# Out:
# <bound method DataFrame.info of            time Soil surface moisture
# 0    2019-12-30            35,4364471
# 1    2020-01-06            44,3363113
# 2    2020-01-13            38,2127304
# 3    2020-01-20            32,6984596
# 4    2020-01-27            42,5319748
# ..          ...                   ...
# 152  2022-11-28            46,3879395
# 153  2022-12-05            55,8530121
# 154  2022-12-12             40,484581
# 155  2022-12-19            49,9482269
# 156  2022-12-26            56,4319801
#
# [157 rows x 2 columns]>

# %%
soildata.tail(5)
# Out:
#            time Soil surface moisture
# 152  2022-11-28            46,3879395
# 153  2022-12-05            55,8530121
# 154  2022-12-12             40,484581
# 155  2022-12-19            49,9482269
# 156  2022-12-26            56,4319801

# %%
soildata['Soil surface moisture'] = soildata['Soil surface moisture'].apply(lambda x: float(x.replace(',', '.')))

# %%
soildata['Soil surface moisture'] = soildata['Soil surface moisture'].round(2)
soildata
# Out:
#            time  Soil surface moisture
# 0    2019-12-30                  35.44
# 1    2020-01-06                  44.34
# 2    2020-01-13                  38.21
# 3    2020-01-20                  32.70
# 4    2020-01-27                  42.53
# ..          ...                    ...
# 152  2022-11-28                  46.39
# 153  2022-12-05                  55.85
# 154  2022-12-12                  40.48
# 155  2022-12-19                  49.95
# 156  2022-12-26                  56.43
#
# [157 rows x 2 columns]

# %%
soildata['Soil surface moisture'].min()
# Out:
# 17.69

# %%
soildata['Soil surface moisture'].max()
# Out:
# 60.76

# %% [markdown]
# Dividir por mês

# %%
soildata['time'] = pd.to_datetime(soildata['time'])
soildata['Month'] = soildata['time'].dt.month

# %%
soildata['Year'] = soildata['time'].dt.year

# %%
soildata

# %% [markdown]
# Graficos de estações de todos os anos(divididos por mês)

# %%
summer = [1,2,3]
Summerdata = soildata[soildata['Month'].isin(summer)]
Summerdata

# %%
month= 1
jan = Summerdata.loc[Summerdata['Month'] == month]
feb = Summerdata.loc[Summerdata['Month'] == 2]
mar = Summerdata.loc[Summerdata['Month'] == 3]

# %%
Summerdata.groupby('Month')['Soil surface moisture'].mean().plot(kind='bar', figsize=(5,5), color='yellow')
plt.xlabel('Month')
plt.ylabel('Soil surface moisture')
plt.title('Summer average soil surface moisture by month')
plt.show()

# %%
fall = [4,5,6]
Falldata = soildata[soildata['Month'].isin(fall)]

# %%
april = Summerdata.loc[Summerdata['Month'] == 4]
may = Summerdata.loc[Summerdata['Month'] == 5]
june = Summerdata.loc[Summerdata['Month'] == 6]

# %%
Falldata.groupby('Month')['Soil surface moisture'].mean().plot(kind='bar', figsize=(10,5), color='orange')
plt.xlabel('Month')
plt.ylabel('Soil surface moisture')
plt.title('Fall average soil surface moisture by month')
plt.show()

# %%
winter = [7,8,9]
Winterdata = soildata[soildata['Month'].isin(winter)]

# %%
july = Summerdata.loc[Summerdata['Month'] == 7]
agus = Summerdata.loc[Summerdata['Month'] == 8]
sept = Summerdata.loc[Summerdata['Month'] == 9]

# %%
Winterdata.groupby('Month')['Soil surface moisture'].mean().plot(kind='bar', figsize=(10,5))
plt.xlabel('Month')
plt.ylabel('Soil surface moisture')
plt.title('Winter average soil surface moisture by month')
plt.show()

# %%
spring = [10,11,12]
Springdata = soildata[soildata['Month'].isin(spring)]

# %%
oct = Springdata.loc[Springdata['Month'] == 10]
nov = Springdata.loc[Springdata['Month'] == 11]
dec = Springdata.loc[Springdata['Month'] == 12]

# %%
Springdata.groupby('Month')['Soil surface moisture'].mean().plot(kind='bar', figsize=(10,5), color='pink')
plt.xlabel('Month')
plt.ylabel('Soil surface moisture')
plt.title('Spring average soil surface moisture by month')
plt.show()

# %%
jan= soildata.loc[soildata['Month'] == 1]
feb = soildata.loc[soildata['Month'] == 2]
mar = soildata.loc[soildata['Month'] == 3]
april = soildata.loc[soildata['Month'] == 4]
may= soildata.loc[soildata['Month'] == 5]
june = soildata.loc[soildata['Month'] == 6]
july = soildata.loc[soildata['Month'] == 7]
agus= soildata.loc[soildata['Month'] == 8]
sep = soildata.loc[soildata['Month'] == 9]
oct = soildata.loc[soildata['Month'] == 10]
nov = soildata.loc[soildata['Month'] == 11]
dec = soildata.loc[soildata['Month'] == 12]

# %% [markdown]
# 2020 Graphic

# %%
data2020 = soildata.loc[soildata['Year'] == 2020]
data2020=data2020.rename(columns={'Soil surface moisture': 'Soil moisture 2020'})
data2020

# %%
jan= data2020.loc[data2020['Month'] == 1]
feb = data2020.loc[data2020['Month'] == 2]
mar = data2020.loc[data2020['Month'] == 3]
april = data2020.loc[data2020['Month'] == 4]
may= data2020.loc[data2020['Month'] == 5]
june = data2020.loc[data2020['Month'] == 6]
july = data2020.loc[data2020['Month'] == 7]
agus= data2020.loc[data2020['Month'] == 8]
sep = data2020.loc[data2020['Month'] == 9]
oct = data2020.loc[data2020['Month'] == 10]
nov = data2020.loc[data2020['Month'] == 11]
dec = data2020.loc[data2020['Month'] == 12]

# %%
colors=['yellow','orange','blue', 'pink']
data2020.groupby('Month')['Soil surface moisture'].mean().plot(kind='bar', figsize=(10,5))
colors=['yellow','orange','blue', 'pink']
plt.xlabel('Month')
plt.ylabel('Soil surface moisture')
plt.title('2020 Average soil surface moisture')
plt.show()

# %% [markdown]
# Dados de 2021

# %%
data2021= soildata.loc[soildata['Year'] == 2021]
data2021 = data2021.rename(columns={'Soil surface moisture': 'Soil moisture 2021'})
data2021
# Out:
#           time  Soil moisture 2021  Month  Year
# 53  2021-01-04               31.54      1  2021
# 54  2021-01-11               29.26      1  2021
# 55  2021-01-18               36.74      1  2021
# 56  2021-01-25               33.87      1  2021
# 57  2021-02-01               31.93      2  2021
# 58  2021-02-08               38.37      2  2021
# 59  2021-02-15               45.40      2  2021
# 60  2021-02-22               43.94      2  2021
# 61  2021-03-01               53.02      3  2021
# 62  2021-03-08               49.34      3  2021
# 63  2021-03-15               41.69      3  2021
# 64  2021-03-22               40.02      3  2021
# 65  2021-03-29               35.84      3  2021
# 66  2021-04-05               34.28      4  2021
# 67  2021-04-12               28.93      4  2021
# 68  2021-04-19               41.56      4  2021
# 69  2021-04-26               40.24      4  2021
# 70  2021-05-03               36.69      5  2021
# 71  2021-05-10               36.48      5  2021
# ...

# %%
jan = data2021.loc[data2021['Month'] == 1]
feb = data2021.loc[data2021['Month'] == 2]
mar = data2021.loc[data2021['Month'] == 3]
april = data2021.loc[data2021['Month'] == 4]
may = data2021.loc[data2021['Month'] == 5]
june = data2021.loc[data2021['Month'] == 6]
july = data2021.loc[data2021['Month'] == 7]
agus = data2021.loc[data2021['Month'] == 8]
sep = data2021.loc[data2021['Month'] == 9]
oct = data2021.loc[data2021['Month'] == 10]
nov = data2021.loc[data2021['Month'] == 11]
dec = data2021.loc[data2021['Month'] == 12]

# %%
colors=['yellow','orange','blue', 'pink']
data2021.groupby('Month')['Soil surface moisture'].mean().plot(kind='bar', figsize=(10,5), color='green')
colors=['yellow','orange','blue', 'pink']
plt.xlabel('Month')
plt.ylabel('Soil surface moisture')
plt.title('2021 Average soil surface moisture')
plt.show()

# %% [markdown]
# Dados 2022

# %%
data2022= soildata.loc[soildata['Year'] == 2022]
data2022=data2022.rename(columns={'Soil surface moisture': 'Soil moisture 2022'})
data2022
# Out:
#           time  Soil moisture 2022  Month  Year
# 105 2022-01-03               60.76      1  2022
# 106 2022-01-10               59.50      1  2022
# 107 2022-01-17               47.88      1  2022
# 108 2022-01-24               41.09      1  2022
# 109 2022-01-31               54.41      1  2022
# 110 2022-02-07               55.51      2  2022
# 111 2022-02-14               53.68      2  2022
# 112 2022-02-21               55.32      2  2022
# 113 2022-02-28               44.75      2  2022
# 114 2022-03-07               55.50      3  2022
# 115 2022-03-14               54.13      3  2022
# 116 2022-03-21               50.15      3  2022
# 117 2022-03-28               50.22      3  2022
# 118 2022-04-04               48.18      4  2022
# 119 2022-04-11               40.39      4  2022
# 120 2022-04-18               47.88      4  2022
# 121 2022-04-25               37.21      4  2022
# 122 2022-05-02               31.47      5  2022
# 123 2022-05-09               33.85      5  2022
# ...

# %%
jan = data2022.loc[data2022['Month'] == 1]
feb = data2022.loc[data2022['Month'] == 2]
mar = data2022.loc[data2022['Month'] == 3]
april = data2022.loc[data2022['Month'] == 4]
may = data2022.loc[data2022['Month'] == 5]
june = data2022.loc[data2022['Month'] == 6]
july = data2022.loc[data2022['Month'] == 7]
agus = data2022.loc[data2022['Month'] == 8]
sep = data2022.loc[data2022['Month'] == 9]
oct = data2022.loc[data2022['Month'] == 10]
nov = data2022.loc[data2022['Month'] == 11]
dec = data2022.loc[data2022['Month'] == 12]

# %%
colors=['yellow','orange','blue', 'pink']
data2022.groupby('Month')['Soil surface moisture'].mean().plot(kind='bar', figsize=(10,5), color='gray')
colors=['yellow','orange','blue', 'pink']
plt.xlabel('Month')
plt.x_sticks
plt.ylabel('Soil surface moisture')
plt.title('2022 Average soil surface moisture')
plt.show()

# %%
from matplotlib.font_manager import FontProperties
data2020.groupby('Month')['Soil moisture 2020'].mean().plot(kind='line', figsize=(16,6), color='blue')
data2021.groupby('Month')['Soil moisture 2021'].mean().plot(kind='line', figsize=(16,6), color='green')
data2022.groupby('Month')['Soil moisture 2022'].mean().plot(kind='line', figsize=(16,6), color='red')
plt.xlabel('Month')
plt.ylabel('Soil surface moisture(%)')
plt.title('Average Soil Surface Moisture 2020-2022')
plt.legend(loc='upper left', prop=FontProperties(size=10
))
plt.show()

# %%
#exemplo 1
fig, ax = plt.subplots(figsize =(16,6))
x = [num for num in range(1,9)]
y = (10,60)
ax.set_title('Average soil', fontsize = 18)
ax.set_xlabel('Meses', fontsize = 14)
ax.set_xticks(x)
ax.set_xticklabels(
    ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'set', 'oct', 'nov', 'dec']

)
plt.xticks(fontsize=12)
ax.set_ylabel('Quantidade', fontsize = 14)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-bec47bd4150b> in <cell line: 6>()
#       4 y = (10,60)
#       5
# ----> 6 ax.plot(x, y , color='navy', linestyle = 'dotted', linewidth=2, marker= 's')
#       7
#       8 ax.set_title('Average soil', fontsize = 18)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1686         """
#    1687         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689         for line in lines:
#    1690             self.add_line(line)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     309                 this += args[0],
#     310                 args = args[1:]
# ...

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (125, 3)
# (125,)

# %%
from sklearn.preprocessing import StandardScaler
std=StandardScaler()
X_train_std=std.fit_transform(x_train)
X_test_std=std.transform(x_test)
X_train_std #normalizaton
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-783e7c1f92fe> in <cell line: 3>()
#       1 from sklearn.preprocessing import StandardScaler
#       2 std=StandardScaler()
# ----> 3 X_train_std=std.fit_transform(x_train)
#       4 X_test_std=std.transform(x_test)
#       5 X_train_std #normalizaton
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     876         if y is None:
# ...
